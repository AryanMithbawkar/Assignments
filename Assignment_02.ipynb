# %%
#1. Download the dataset: Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#2. Load the dataset into the tool.
data=pd.read_csv('penguins_size.csv')
data=pd.DataFrame(data)

# %%
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
a=data['species'].value_counts()
a
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
#3. Perform Below Visualizations.
#Univariate Analysis
sns.countplot(data=data,x='species',color='slateblue',edgecolor='green')
plt.xlabel("Species")
plt.ylabel("count")
plt.title('Sample count of species')
# Out:
# Text(0.5, 1.0, 'Sample count of species')

# %%
b=data['species'].unique()
plt.pie(a,labels=b,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7c8b1945ce50>,
# ...
#  [Text(0.19980052901159365, 1.0817022458175296, 'Adelie'),
#   Text(-0.7918938277833127, -0.7634816078457249, 'Chinstrap'),
#   Text(0.894618705053837, -0.6400448207491378, 'Gentoo')],
#  [Text(0.10898210673359653, 0.5900194068095616, '44%'),
#   Text(-0.4319420878818069, -0.4164445133703954, '36%'),
#   Text(0.4879738391202747, -0.34911535677225697, '20%')])

# %%
sns.countplot(data=data,x='island',color='Gold',edgecolor="Red")
plt.xlabel("islands")
plt.ylabel("count")
plt.title('Sample count of collected from each island')
# Out:
# Text(0.5, 1.0, 'Sample count of collected from each island')

# %%
sns.countplot(data=data,x='sex',hue='sex')
plt.xlabel("genders")
plt.ylabel("count")
plt.title('Sex of penguins in sample')
# Out:
# Text(0.5, 1.0, 'Sex of penguins in sample')

# %%
sns.histplot(data=data,x='culmen_length_mm',hue='species')
plt.xlabel("culmen length in mm")
plt.ylabel("count of readings")
# Out:
# Text(0, 0.5, 'count of readings')

# %%
sns.histplot(data=data,x='culmen_depth_mm',hue='species')
plt.xlabel("culmen depth in mm")
plt.ylabel("count of readings")
# Out:
# Text(0, 0.5, 'count of readings')

# %%
sns.histplot(data=data,x='flipper_length_mm',hue='species')
plt.xlabel("flipper length in mm")
plt.ylabel("count of readings")
# Out:
# Text(0, 0.5, 'count of readings')

# %%
sns.histplot(data=data,x='body_mass_g',hue='species')
plt.xlabel("culmen length in mm")
plt.ylabel("count of readings")
# Out:
# Text(0, 0.5, 'count of readings')

# %%
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
sns.set_palette('muted')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='culmen_length_mm')
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.boxplot(data=data,y='culmen_depth_mm')
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.boxplot(data=data,y='flipper_length_mm')
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.boxplot(data=data,y='body_mass_g')
plt.ylabel("body mass in grams")
# Out:
# Text(0, 0.5, 'body mass in grams')

# %%
#Bi- Variate Analysis
sns.barplot(data=data,x='species',y='culmen_length_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("culmen length in mm")
# Out:
# Text(0, 0.5, 'culmen length in mm')

# %%
sns.set_palette('tab20c')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.barplot(data=data,x='species',y='culmen_length_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.barplot(data=data,x='species',y='culmen_depth_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.barplot(data=data,x='species',y='flipper_length_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.barplot(data=data,x='species',y='body_mass_g',hue='species')
plt.xlabel("Species")
plt.ylabel("body mass in grams")
# Out:
# Text(0, 0.5, 'body mass in grams')

# %%
sns.set_palette('colorblind')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.barplot(data=data,x='species',y='culmen_length_mm',hue='sex')
plt.xlabel("Species")
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.barplot(data=data,x='species',y='culmen_depth_mm',hue='sex')
plt.xlabel("Species")
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.barplot(data=data,x='species',y='flipper_length_mm',hue='sex')
plt.xlabel("Species")
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.barplot(data=data,x='species',y='body_mass_g',hue='sex')
plt.xlabel("Species")
plt.ylabel("body mass in grams")
# Out:
# Text(0, 0.5, 'body mass in grams')

# %%
sns.set_palette('muted')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.boxplot(data=data,x='species',y='culmen_length_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.boxplot(data=data,x='species',y='culmen_depth_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.boxplot(data=data,x='species',y='flipper_length_mm',hue='species')
plt.xlabel("Species")
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.boxplot(data=data,x='species',y='body_mass_g',hue='species')
plt.xlabel("Species")
plt.ylabel("body mass in grams")
# Out:
# Text(0, 0.5, 'body mass in grams')

# %%
sns.set_palette('bright')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.lineplot(data=data,x='body_mass_g',y='culmen_length_mm',hue='species')
plt.xlabel("body_mass_g")
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.scatterplot(data=data,x='body_mass_g',y='culmen_depth_mm',hue='species')
plt.xlabel("body_mass_g")
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.lineplot(data=data,x='body_mass_g',y='flipper_length_mm',hue='species')
plt.xlabel("body_mass_g")
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.scatterplot(data=data,x='flipper_length_mm',y='culmen_length_mm',hue='species')
plt.ylabel("culmen depth in mm")
plt.xlabel("flipper length in mm")
# Out:
# Text(0.5, 0, 'flipper length in mm')

# %%
sns.pairplot(data=data,hue='species')

# %%
#Multi-Variate Analysis
c=data.corr()
c
# Out:
# <ipython-input-105-c758e6a4cae3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=data.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(c,cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
#4. Perform descriptive statistics on the dataset
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
#5. Check for Missing values and deal with them.
data.isnull().value_counts()
# Out:
# species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  sex
# False    False   False             False            False              False        False    334
#                                                                                     True       8
#                  True              True             True               True         True       2
# dtype: int64

# %%
data['culmen_length_mm'].fillna(data['culmen_length_mm'].mean(),inplace=True)
data['culmen_depth_mm'].fillna(data['culmen_depth_mm'].mean(),inplace=True)
data['flipper_length_mm'].fillna(data['flipper_length_mm'].mean(),inplace=True)
data['body_mass_g'].fillna(data['body_mass_g'].mean(),inplace=True)
data['sex'].fillna(data['sex'].mode()[0],inplace=True)

# %%
data['sex'].value_counts()
# Out:
# MALE      178
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
data.loc[data['sex'] == ".", 'sex'] = data['body_mass_g'].mode()

# %%
data['sex'].value_counts()
# Out:
# MALE      178
# FEMALE    165
# Name: sex, dtype: int64

# %%
data.isnull().value_counts()
# Out:
# species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  sex
# False    False   False             False            False              False        False    343
#                                                                                     True       1
# dtype: int64

# %%
#6. Find the outliers and replace them outliers
sns.set_palette('muted')
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='culmen_length_mm')
plt.ylabel("culmen length in mm")
plt.subplot(2,2,2)
sns.boxplot(data=data,y='culmen_depth_mm')
plt.ylabel("culmen depth in mm")
plt.tight_layout(pad=2.0)
plt.subplot(2,2,3)
sns.boxplot(data=data,y='flipper_length_mm')
plt.ylabel("flipper length in mm")
plt.subplot(2,2,4)
sns.boxplot(data=data,y='body_mass_g')
plt.ylabel("body mass in grams")
# Out:
# Text(0, 0.5, 'body mass in grams')

# %%
#7. Check for Categorical columns and perform encoding.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                343 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['species']=le.fit_transform(data['species'])
data['island']=le.fit_transform(data['island'])
data['sex']=le.fit_transform(data['sex'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    int64
#  1   island             344 non-null    int64
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 18.9 KB

# %%
#9. Split the data into dependent and independent variables.
x=data.iloc[:,1:6]
x.head(2)
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0       2              39.1             18.7              181.0       3750.0
# 1       2              39.5             17.4              186.0       3800.0

# %%
y=data.iloc[:,:1]
y.head(2)
# Out:
#    species
# 0        0
# 1        0

# %%
#10. Scaling the data
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.84407623, -0.88708123,  0.78774251, -1.42248782, -0.56578921],
#        [ 1.84407623, -0.81349399,  0.12655633, -1.06535169, -0.50316788],
#        [ 1.84407623, -0.66631952,  0.43171918, -0.42250666, -1.19200251],
#        ...,
#        [-0.91402039,  1.1917582 , -0.73807176,  1.50602843,  1.93906399],
#        [-0.91402039,  0.23512413, -1.19581604,  0.79175618,  1.25022936],
#        [-0.91402039,  1.09977416, -0.53462985,  0.8631834 ,  1.50071468]])

# %%
#11. Split the data into training and testing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
#12. Build the Model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
lr=LinearRegression()
r=Ridge()
l=Lasso()
dt=DecisionTreeClassifier(criterion='entropy',random_state=0)
rf=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)

# %%
#13. Train the Model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
l.fit(x_train,y_train)
# Out:
# Lasso()

# %%
r.fit(x_train,y_train)
# Out:
# Ridge()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
rf.fit(x_train,y_train)
# Out:
# <ipython-input-134-895403b03771>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
#14. Test the Model
pred1=lr.predict(x_test)
pred2=l.predict(x_test)
pred3=r.predict(x_test)
pred4=dt.predict(x_test)
pred5=rf.predict(x_test)

# %%
print(pred1)
print(pred2)
print(pred3)
print(pred4)
print(pred5)
# Out:
# [[ 0.44366061]
#  [ 0.02259031]
#  [ 0.25059585]
#  [ 2.09351405]
#  [-0.05254437]
#  [ 1.81420741]
#  [ 0.17808246]
#  [ 1.22440614]
#  [ 1.7316795 ]
#  [ 0.1220018 ]
#  [ 0.28903305]
#  [ 1.83387787]
#  [ 0.21694871]
#  [ 1.92507493]
#  [ 1.8218475 ]
#  [ 0.19688764]
#  [ 0.2312629 ]
#  [ 1.76471008]
#  [ 0.37899751]
#  [-0.07260191]
#  [ 1.90391814]
#  [ 0.16348999]
#  [ 0.89332089]
#  [ 0.01341068]
#  [ 2.0445034 ]
#  [ 2.28615027]
#  [ 1.72148612]
#  [ 0.22375753]
#  [ 0.3917737 ]
#  [ 1.70217236]
#  [ 1.94363496]
#  [ 0.87174988]
#  [-0.03044603]
#  [ 0.26296401]
#  [-0.11940304]
#  [ 0.86473086]
#  [ 2.01957943]
#  [ 0.87148676]
#  [ 0.08213588]
#  [ 0.54904671]
#  [ 0.01646911]
#  [ 0.47977628]
#  [-0.01739321]
#  [ 1.77637618]
#  [ 1.82513025]
#  [-0.08568278]
#  [ 1.98408357]
#  [ 1.1174362 ]
#  [ 0.14199508]
#  [ 2.00025994]
#  [-0.00456893]
#  [ 0.05581751]
#  [ 0.20297161]
#  [ 0.5335899 ]
#  [ 0.0325834 ]
#  [ 0.65678145]
#  [ 0.08371446]
#  [ 2.20886251]
# ...

# %%
#15. Measure the performance using Evaluation Metrics.
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error,classification_report

# %%
print(f"for linear regression model \nMSE={mean_squared_error(y_test,pred1)} \nR2_score={r2_score(y_test,pred1)}")
print(f"\nfor lasso model \nMSE={mean_squared_error(y_test,pred2)} \nR2_score={r2_score(y_test,pred2)}")
print(f"\nfor ridge model \nMSE={mean_squared_error(y_test,pred3)} \nR2_score={r2_score(y_test,pred3)}")
print(f"\nfor Decision tree model \naccuracy score={accuracy_score(y_test,pred4)} \nR2_score={r2_score(y_test,pred4)}")
print(f"\nfor Random tree model \naccuracy score={accuracy_score(y_test,pred5)} \nR2_score={r2_score(y_test,pred5)}")
# Out:
# for linear regression model
# MSE=0.05892051226544982
# R2_score=0.9288427578536059
#
# for lasso model
# MSE=0.8338514957264958
# R2_score=-0.00702744280680867
#
# for ridge model
# MSE=0.059109564497296055
# R2_score=0.9286144428759765
#
# for Decision tree model
# accuracy score=1.0
# R2_score=1.0
#
# for Random tree model
# accuracy score=0.9807692307692307
# R2_score=0.9419383653416704
